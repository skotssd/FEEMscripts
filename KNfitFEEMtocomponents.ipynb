% %% [markdown]
% # FIRST RUN generateFEEMplots
%
% after running generateFEEMplots the variables F em and ex will be available for the fitting routine here.
%
% component options available here (taken from OpenFluor database https://openfluor.lablicate.com/)
%
% https://docs.google.com/spreadsheets/d/1-Psv4vUMNjIBb6seB5hVN828BOHneAJuYYlWnzZ11J8/edit?usp=sharing
%
% use ID to select sample for fitting.

% %%
% load the data. you may have to restart kernel after every data change

clear

load /home/jovyan/data/Katharina/KDBFB-1.mat
%load /home/jovyan/data/Katharina/KDBFB-2.mat
%load /home/jovyan/data/Katharina/KDBFB-3.mat
%load /home/jovyan/data/Katharina/KWDFB-1.mat
%load /home/jovyan/data/Katharina/KWDFB-2.mat
%load /home/jovyan/data/Katharina/KWDFB-3.mat
%load /home/jovyan/data/Katharina/KWDMG-1.mat
%load /home/jovyan/data/Katharina/KWDMG-2.mat
%load /home/jovyan/data/Katharina/KPBMB-1.mat
%load /home/jovyan/data/Katharina/KPBMB-2.mat
%load /home/jovyan/data/Katharina/KPBMB-3.mat
%load /home/jovyan/data/Katharina/KWD-OMBF-1.mat
%load /home/jovyan/data/Katharina/KWD-OMBF-2.mat
%load /home/jovyan/data/Katharina/KWD-OMBF-3.mat
%load /home/jovyan/data/Katharina/KDB-IFB-1.mat
%load /home/jovyan/data/Katharina/KDB-IFB-2.mat
%load /home/jovyan/data/Katharina/KDB-IFB-3.mat
%load /home/jovyan/data/Katharina/KDB-OMB-1.mat
%load /home/jovyan/data/Katharina/KDB-OMB-2.mat
%load /home/jovyan/data/Katharina/KWD-IFB2-1.mat
%load /home/jovyan/data/Katharina/KWD-IFB2-2.mat
%load /home/jovyan/data/Katharina/KWD-IFB2-3.mat
%load /home/jovyan/data/Katharina/KWD-OMBC-1.mat
%load /home/jovyan/data/Katharina/KWD-OMBC-2.mat
%load /home/jovyan/data/Katharina/KWD-OMBC-3.mat
%load /home/jovyan/data/Katharina/KND-IS-1.mat
%load /home/jovyan/data/Katharina/KND-IS-2.mat
%load /home/jovyan/data/Katharina/KND-IS-3.mat
%load /home/jovyan/data/Katharina/KPB-IS-1.mat
%load /home/jovyan/data/Katharina/KPB-IS-2.mat
%load /home/jovyan/data/Katharina/KPB-IS-3.mat
%load /home/jovyan/data/Katharina/KND-IFB-1.mat
%load /home/jovyan/data/Katharina/KND-IFB-2.mat
%load /home/jovyan/data/Katharina/KND-IFB-3.mat

% %% [markdown]
% # define functions to manipulate the data
%
% you can compress these boxes by clicking to the left so they won't "clutter" up the screen

% %%
function makecontourplot(F,em,ex)
 colormap('jet')
 h=surf(em,ex,F);
 shading interp
 hold on; [Cref,h]=contour3(em,ex,F,3,'k'); set(h,'linewidth',2); 
 set(gca,'linewidth',2,'fontsize',12)
 axis([min(em) max(em) min(ex) max(ex) 0 max(max(F))])
 view([0 90])
 %hold on; plot3([250 600],[450 450],[0 0],'k','linewidth',2)
 %hold on; plot3([600 600],[220 450],[0 0],'k','linewidth',2)
 h=xlabel('Emission (nm)'); set(h,'fontsize',12)
 h=ylabel('Excitation (nm)');  set(h,'fontsize',12)
 %add scale bar
 colorbar 
end

% %% [markdown]
% # visualize the original data

% %%
%contour plot over colourmap.
graphics_toolkit ("notebook"); 
makecontourplot(F,em,ex)

% %%
% load the model

%load ID15154.mat %ex 250-500 em 300-550
%load ID13953.mat %ex 250-500 em 300-550
%load ID13953.mat %ex 250-500 em 300-550
%load ID6307.mat %ex 275-450 em 230-440
%load ID9659.mat %EX range 240 to 450 EM range 300 to 600
%load IDNoneatthemoment.mat %ex 200-450 em 250-600
%load ID6173.mat %245-450 and 300-560
%load ID9954.mat %245-450 and 300-560
%load ID6509.mat %230-450	260-550
%load ID231.mat %230-450	260-550
%load ID11.mat %600-220.68	210.901-617.135

%load ID2882.mat %240-450	280-600
%load ID2.mat %600-220.68	210.901-617.135
%load ID7.mat %600-220.68	210.901-617.135
%load ID12.mat %600-220.68	210.901-617.135
%load ID14.mat %600-220.68	210.901-617.135
%load ID17.mat %600-220.68	210.901-617.135
%load ID29.mat %600-220.68	210.901-617.135
%load ID35.mat %600-220.68	210.901-617.135
%load ID45.mat %600-220.68	210.901-617.135
%load ID46.mat %600-220.68	210.901-617.135
%load ID48.mat %600-220.68	210.901-617.135
%load ID49.mat %600-220.68	210.901-617.135
%load ID55.mat %600-220.68	210.901-617.135
%load ID243.mat %600-220.68	210.901-617.135
%load ID680.mat %600-220.68	210.901-617.135
%load ID694.mat %600-220.68	210.901-617.135
%load ID943.mat %600-220.68	210.901-617.135
%load ID1278.mat %600-220.68	210.901-617.135
%load ID2101.mat %600-220.68	210.901-617.135
%load ID1257.mat %600-220.68	210.901-617.135
%load ID5842.mat %600-220.68	210.901-617.135
%load ID7794.mat %600-220.68	210.901-617.135
%load ID5511.mat %600-220.68	210.901-617.135
load ID15154.mat %600-220.68	210.901-617.135

% interpolate over this em and ex for the dataset

for i=1:C
    istr=num2str(i);
    txt=['Cem',istr','i=interp1(Cem,Cem',istr,',em); Cem',istr,'i(isnan(Cem',istr,'i))=0;'];
    eval(txt)
    txt=['Cex',istr','i=interp1(Cex,Cex',istr,',ex); Cex',istr,'i(isnan(Cex',istr,'i))=0;'];
    eval(txt)
    %Cex1i=interp1(Cex,Cex1,ex); Cex1i(isnan(Cex1i))=0; 
    %size(Cex1i)
    %size(Cem1i)
    txt=['F',istr,'=Cex',istr,'i''*Cem',istr,'i'';']; eval(txt);
    subplot(3,3,i); hold on;
    txt=['contour(em,ex,F',istr,')']; eval(txt)
    title(istr)
end

% %%
% fit to a linear model
FnoNaN=F; FnoNaN(isnan(FnoNaN))=0; % get rid of NaN in the original matrix

%fcn=@(p)(sum(sum((FnoNaN-((10^p(1)).*F1+(10^p(2)).*F2+(10^p(3)).*F3+(10^p(4)).*F4+(10^p(5)).*F5)).^2)));
%p0=[2;2;2;2;2]; 
    
runningtxt=['fcn=@(p)(sum(sum((FnoNaN-('];
for i=1:C
    istr=num2str(i);
    runningtxt=[runningtxt,'(10^p(',istr,')).*F',istr,'+'];
    p0(i)=1;
end

runningtxt=runningtxt(1:length(runningtxt)-1); txt=[runningtxt,')).^2)));']; eval(txt);
options=optimset('MaxFunEvals',10000,'display','off','TolFun',1e-5,'TolX',1e-5);
[pmin,fval]=fminsearch(fcn,p0,options); p=10.^pmin

Ffit=zeros(size(F));
for i=1:C
    istr=num2str(i);
    txt=['Ffit=Ffit+p(i)*F',istr,';']; eval(txt);
end
sumF=sum(sum(FnoNaN)); sumFfit=sum(sum(Ffit)); 
overallfit=100*(sumF-sumFfit)./sumF

%fcn
% Out:
% p =    71.104   13.124   78.585   55.584   28.193
% overallfit = 23.217

% %%
subplot(221)
contour(em,ex,F)
subplot(222)
contour(em,ex,Ffit)
subplot(223)
contour(em,ex,F-Ffit)
